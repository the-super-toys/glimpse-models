# %%
from torch.utils.data.dataset import Dataset
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt
import glob
from PIL import Image
import torch
from torch import nn, optim

# %%
# create data_loader for images
class SaliencyDataset(Dataset):
    def __init__(self):
        self.heatmap_path_list = glob.glob(f"../heatmaps/*.jpg")
        
    def __getitem__(self, index):
        heatmap_path = self.heatmap_path_list[index]
        image_path = "../images/"+heatmap_path.split('/')[-1]
                
        heatmap = Image.open(heatmap_path)
        image = Image.open(image_path).convert('RGB')
        
        to_tensot = transforms.ToTensor()
        resize = transforms.Resize(60)
        
        return to_tensot(resize(heatmap)), to_tensot(image)

    def __len__(self):
        return len(self.heatmap_path_list)

# %%
batch_size = 4

dataset = SaliencyDataset()
loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
heatmaps, images = next(iter(loader))

print(heatmaps.shape, images.shape)

plt.imshow(images[0].permute(1, 2, 0))
plt.show()

heatmap = heatmaps[0].view(60, 80)
plt.imshow(heatmap, cmap='Greys_r')
plt.show()

heatmap = torch.softmax(heatmaps[0].view(-1), dim=0).view(60, 80)
plt.imshow(heatmap, cmap='Greys_r')
plt.show()
# Out:
# torch.Size([4, 1, 60, 80]) torch.Size([4, 3, 480, 640])

# %%
class ResBlock(nn.Module):
    def __init__(self, channels):
        super(ResBlock, self).__init__()
        
        self.resblock = nn.Sequential(
            nn.Conv2d(channels, channels, kernel_size=3, padding=1),
            nn.InstanceNorm2d(channels, affine=True),
            nn.ReLU(),
            nn.Conv2d(channels, channels, kernel_size=3, padding=1),
            nn.InstanceNorm2d(channels, affine=True),
        )
        
    def forward(self, x):
        out = self.resblock(x)
        return out + x

class MicroResNet(nn.Module):
    def __init__(self):
        super(MicroResNet, self).__init__()
        
        self.downsampler = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=9, padding=4),
            nn.InstanceNorm2d(16, affine=True),
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=3, padding=1, stride=2),
            nn.InstanceNorm2d(32, affine=True),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, padding=1, stride=2),
            nn.InstanceNorm2d(64, affine=True),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=3, padding=1, stride=2),
            nn.InstanceNorm2d(128, affine=True),
            nn.ReLU(),
        )
        
        self.residual = nn.Sequential(
            ResBlock(128),
            ResBlock(128),
            ResBlock(128),
            ResBlock(128)
        )
        
        self.segmentator = nn.Sequential(
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.InstanceNorm2d(64, affine=True),
            nn.ReLU(),
            nn.Conv2d(64, 32, kernel_size=3, padding=1),
            nn.InstanceNorm2d(32, affine=True),
            nn.ReLU(),
            nn.Conv2d(32, 1, kernel_size=9, padding=4),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        out = self.downsampler(x)
        out = self.residual(out)
        out = self.segmentator(out)
        return out

# %%
model = MicroResNet()

# %%
heatmaps, images = next(iter(loader))

pred = model(images)
print(pred.shape, heatmaps.shape)
# Out:
# torch.Size([4, 1, 60, 80]) torch.Size([4, 1, 60, 80])

# %%
epochs = 1

optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()

model.train()
for e in range(1, epochs+1):
    total_loss = 0
    batch = 0
    for heatmaps, images in loader:
        batch += 1
        optimizer.zero_grad()
        batch_size = images.size(0)

        pred = model.forward(images)
        
        pred_softmax = torch.softmax(pred.view(batch_size, -1), dim=1)
        heatmaps_softmax = torch.softmax(heatmaps.view(batch_size, -1), dim=1)
        loss = criterion(pred, heatmaps)
        
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        
        print(f"EPOCH {e} ({batch}/{len(loader)}) - loss {total_loss/batch:.4f}", end='\r')
# Out:
# EPOCH 1 (383/2016) - loss 0.0190
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-127-8f4f535a9029> in <module>
#      13         batch_size = images.size(0)
#      14
# ---> 15         pred = model.forward(images)
#      16
#      17         pred_softmax = torch.softmax(pred.view(batch_size, -1), dim=1)
#
# <ipython-input-117-1f5196ddf7a6> in forward(self, x)
#      54     def forward(self, x):
#      55         out = self.downsampler(x)
# ---> 56         out = self.residual(out)
#      57         out = self.segmentator(out)
#      58         return out
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-117-1f5196ddf7a6> in forward(self, x)
#      12
#      13     def forward(self, x):
# ---> 14         out = self.resblock(x)
#      15         return out + x
#      16
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     318     def forward(self, input):
#     319         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 320                         self.padding, self.dilation, self.groups)
#     321
#     322
#
# KeyboardInterrupt:

# %%
with torch.no_grad():
    model.eval()
    heatmaps, images = next(iter(loader))

    preds = model(images)

    plt.imshow(images[0].permute(1, 2, 0))
    plt.show()

    heatmap = torch.softmax(heatmaps[0].view(-1), dim=0).view(60, 80) # heatmaps[0].view(60, 80)
    plt.imshow(heatmap, cmap='Greys_r')
    plt.show()

    pred = torch.softmax(preds[0].view(-1), dim=0).view(60, 80) # preds[0].view(60, 80)
    plt.imshow(pred, cmap='Greys_r')
    plt.show()
