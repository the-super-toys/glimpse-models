# %%
import torch
from torch import nn
import torch.onnx
import tensorflow as tf 
from onnx_tf.backend import prepare
import onnx

# %%
class ResBlock(nn.Module):
    def __init__(self, channels):
        super(ResBlock, self).__init__()
        
        self.resblock = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(channels, channels, kernel_size=3),
            nn.InstanceNorm2d(channels, affine=True),
            nn.ReLU(),
            nn.ReflectionPad2d(1),
            nn.Conv2d(channels, channels, kernel_size=3),
            nn.InstanceNorm2d(channels, affine=True),
        )
        
    def forward(self, x):
        out = self.resblock(x)
        return out + x
    
class Upsample2d(nn.Module):
    def __init__(self, scale_factor):
        super(Upsample2d, self).__init__()
        
        self.interp = nn.functional.interpolate
        self.scale_factor = scale_factor
        
    def forward(self, x):
        x = self.interp(x, scale_factor=self.scale_factor, mode='nearest')
        return x

class MicroResNet(nn.Module):
    def __init__(self):
        super(MicroResNet, self).__init__()
        
        self.downsampler = nn.Sequential(
            nn.ReflectionPad2d(4),
            nn.Conv2d(3, 8, kernel_size=9, stride=4),
            nn.InstanceNorm2d(8, affine=True),
            nn.ReLU(),
            nn.ReflectionPad2d(1),
            nn.Conv2d(8, 16, kernel_size=3, stride=2),
            nn.InstanceNorm2d(16, affine=True),
            nn.ReLU(),
            nn.ReflectionPad2d(1),
            nn.Conv2d(16, 32, kernel_size=3, stride=2),
            nn.InstanceNorm2d(32, affine=True),
            nn.ReLU(),
        )
        
        self.residual = nn.Sequential(
            ResBlock(32),
            nn.Conv2d(32, 64, kernel_size=1, bias=False, groups=32),
            ResBlock(64),
        )
        
        self.segmentator = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(64, 16, kernel_size=3),
            nn.InstanceNorm2d(16, affine=True),
            nn.ReLU(),
            Upsample2d(scale_factor=2),
            nn.ReflectionPad2d(4),
            nn.Conv2d(16, 1, kernel_size=9),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        out = self.downsampler(x)
        out = self.residual(out)
        out = self.segmentator(out)
        return out

# %%
model = MicroResNet()

checkpoint = torch.load('../models/model_fast.pt')
model.load_state_dict(checkpoint)
model.eval()
# Out:
# MicroResNet(
#   (downsampler): Sequential(
#     (0): ReflectionPad2d((4, 4, 4, 4))
#     (1): Conv2d(3, 8, kernel_size=(9, 9), stride=(4, 4))
#     (2): InstanceNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (3): ReLU()
#     (4): ReflectionPad2d((1, 1, 1, 1))
#     (5): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2))
#     (6): InstanceNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (7): ReLU()
#     (8): ReflectionPad2d((1, 1, 1, 1))
#     (9): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2))
#     (10): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (11): ReLU()
#   )
#   (residual): Sequential(
#     (0): ResBlock(
#       (resblock): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (3): ReLU()
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       )
#     )
#     (1): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), groups=32, bias=False)
#     (2): ResBlock(
#       (resblock): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (3): ReLU()
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       )
#     )
#   )
#   (segmentator): Sequential(
#     (0): ReflectionPad2d((1, 1, 1, 1))
#     (1): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): InstanceNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (3): ReLU()
#     (4): Upsample2d()
#     (5): ReflectionPad2d((4, 4, 4, 4))
#     (6): Conv2d(16, 1, kernel_size=(9, 9), stride=(1, 1))
#     (7): Sigmoid()
#   )
# )

# %%
class MicroResNetIOS(nn.Module):
    def __init__(self):
        super(MicroResNetIOS, self).__init__()
        self.micro_res_net = model
        
    def forward(self, x):
        x = x.permute(0,3,1,2)
        out = self.micro_res_net(x)
        return out.permute(0,2,3,1)

model_ios = MicroResNetIOS()

# %%
with torch.no_grad():
    x = torch.randn(1, 3, 240, 320, requires_grad=True)
    torch_out = torch.onnx.export(model, x, "../models/model_fast.onnx", export_params=True)

# %%
onnx_model = onnx.load("../models/model_fast.onnx")  # load onnx model
tf_rep = prepare(onnx_model)  # prepare tf representation
tf_rep.export_graph("../models/model_fast.pb")  # export the model
# Out:
# /usr/local/lib/python3.6/site-packages/onnx_tf/common/handler_helper.py:73: UserWarning: Unknown op ConstantFill in domain `ai.onnx`.
#   handler.ONNX_OP, handler.DOMAIN or "ai.onnx"))
# /usr/local/lib/python3.6/site-packages/onnx_tf/common/handler_helper.py:73: UserWarning: Unknown op MeanVarianceNormalization in domain `ai.onnx`.
#   handler.ONNX_OP, handler.DOMAIN or "ai.onnx"))
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow/python/ops/control_flow_ops.py:3637: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
g = tf.GraphDef()
g.ParseFromString(open("../models/model_fast.pb", "rb").read())

# g.node
[str(idx)+" "+n.name for (idx, n) in enumerate(g.node)] #if n.name == 'PyFunc']
# Out:
# ['0 Const',
#  '1 Const_1',
#  '2 Const_2',
#  '3 Const_3',
#  '4 Const_4',
#  '5 Const_5',
#  '6 Const_6',
#  '7 Const_7',
#  '8 Const_8',
#  '9 Const_9',
#  '10 Const_10',
#  '11 Const_11',
#  '12 Const_12',
#  '13 Const_13',
#  '14 Const_14',
#  '15 Const_15',
#  '16 Const_16',
#  '17 Const_17',
#  '18 Const_18',
#  '19 Const_19',
#  '20 Const_20',
#  '21 Const_21',
#  '22 Const_22',
#  '23 Const_23',
#  '24 Const_24',
#  '25 Const_25',
#  '26 Const_26',
#  '27 Const_27',
#  '28 Const_28',
#  '29 Const_29',
#  '30 Const_30',
#  '31 Const_31',
#  '32 Const_32',
#  '33 Const_33',
#  '34 Const_34',
#  '35 input.1',
#  '36 Const_35',
#  '37 MirrorPad',
#  '38 transpose/perm',
#  '39 transpose',
#  '40 Const_36',
#  '41 Pad',
#  '42 Const_37',
#  '43 split/split_dim',
#  '44 split',
#  '45 transpose_1/perm',
#  '46 transpose_1',
#  '47 Const_38',
#  '48 split_1/split_dim',
#  '49 split_1',
#  '50 convolution/dilation_rate',
#  '51 convolution',
#  '52 concat/concat_dim',
#  '53 concat',
#  '54 Add',
#  '55 transpose_2/perm',
#  '56 transpose_2',
#  '57 Reshape/shape',
#  '58 Reshape',
#  '59 Reshape_1/shape',
#  '60 Reshape_1',
#  '61 moments/mean/reduction_indices',
#  '62 moments/mean',
#  '63 moments/StopGradient',
#  '64 moments/SquaredDifference',
#  '65 moments/variance/reduction_indices',
#  '66 moments/variance',
#  '67 instancenorm/add/y',
#  '68 instancenorm/add',
#  '69 instancenorm/Rsqrt',
#  '70 instancenorm/mul',
#  '71 instancenorm/mul_1',
#  '72 instancenorm/mul_2',
#  '73 instancenorm/sub',
#  '74 instancenorm/add_1',
#  '75 Relu',
#  '76 Const_39',
#  '77 MirrorPad_1',
#  '78 transpose_3/perm',
#  '79 transpose_3',
#  '80 Const_40',
#  '81 Pad_1',
#  '82 Const_41',
#  '83 split_2/split_dim',
#  '84 split_2',
#  '85 transpose_4/perm',
#  '86 transpose_4',
#  '87 Const_42',
#  '88 split_3/split_dim',
#  '89 split_3',
#  '90 convolution_1/dilation_rate',
#  '91 convolution_1',
#  '92 concat_1/concat_dim',
#  '93 concat_1',
#  '94 Add_1',
#  '95 transpose_5/perm',
#  '96 transpose_5',
#  '97 Reshape_2/shape',
#  '98 Reshape_2',
#  '99 Reshape_3/shape',
#  '100 Reshape_3',
#  '101 moments_1/mean/reduction_indices',
#  '102 moments_1/mean',
#  '103 moments_1/StopGradient',
#  '104 moments_1/SquaredDifference',
#  '105 moments_1/variance/reduction_indices',
#  '106 moments_1/variance',
#  '107 instancenorm_1/add/y',
#  '108 instancenorm_1/add',
#  '109 instancenorm_1/Rsqrt',
#  '110 instancenorm_1/mul',
#  '111 instancenorm_1/mul_1',
#  '112 instancenorm_1/mul_2',
#  '113 instancenorm_1/sub',
#  '114 instancenorm_1/add_1',
#  '115 Relu_1',
#  '116 Const_43',
#  '117 MirrorPad_2',
#  '118 transpose_6/perm',
#  '119 transpose_6',
#  '120 Const_44',
#  '121 Pad_2',
#  '122 Const_45',
#  '123 split_4/split_dim',
#  '124 split_4',
#  '125 transpose_7/perm',
#  '126 transpose_7',
#  '127 Const_46',
#  '128 split_5/split_dim',
#  '129 split_5',
#  '130 convolution_2/dilation_rate',
#  '131 convolution_2',
#  '132 concat_2/concat_dim',
#  '133 concat_2',
#  '134 Add_2',
#  '135 transpose_8/perm',
#  '136 transpose_8',
#  '137 Reshape_4/shape',
#  '138 Reshape_4',
#  '139 Reshape_5/shape',
#  '140 Reshape_5',
#  '141 moments_2/mean/reduction_indices',
#  '142 moments_2/mean',
#  '143 moments_2/StopGradient',
#  '144 moments_2/SquaredDifference',
#  '145 moments_2/variance/reduction_indices',
#  '146 moments_2/variance',
#  '147 instancenorm_2/add/y',
#  '148 instancenorm_2/add',
#  '149 instancenorm_2/Rsqrt',
#  '150 instancenorm_2/mul',
#  '151 instancenorm_2/mul_1',
#  '152 instancenorm_2/mul_2',
#  '153 instancenorm_2/sub',
#  '154 instancenorm_2/add_1',
#  '155 Relu_2',
#  '156 Const_47',
#  '157 MirrorPad_3',
#  '158 transpose_9/perm',
#  '159 transpose_9',
#  '160 Const_48',
#  '161 Pad_3',
#  '162 Const_49',
#  '163 split_6/split_dim',
#  '164 split_6',
#  '165 transpose_10/perm',
#  '166 transpose_10',
#  '167 Const_50',
#  '168 split_7/split_dim',
#  '169 split_7',
#  '170 convolution_3/dilation_rate',
#  '171 convolution_3',
#  '172 concat_3/concat_dim',
#  '173 concat_3',
#  '174 Add_3',
#  '175 transpose_11/perm',
#  '176 transpose_11',
#  '177 Reshape_6/shape',
#  '178 Reshape_6',
#  '179 Reshape_7/shape',
#  '180 Reshape_7',
#  '181 moments_3/mean/reduction_indices',
#  '182 moments_3/mean',
#  '183 moments_3/StopGradient',
#  '184 moments_3/SquaredDifference',
#  '185 moments_3/variance/reduction_indices',
#  '186 moments_3/variance',
#  '187 instancenorm_3/add/y',
#  '188 instancenorm_3/add',
#  '189 instancenorm_3/Rsqrt',
#  '190 instancenorm_3/mul',
#  '191 instancenorm_3/mul_1',
#  '192 instancenorm_3/mul_2',
#  '193 instancenorm_3/sub',
#  '194 instancenorm_3/add_1',
#  '195 Relu_3',
#  '196 Const_51',
#  '197 MirrorPad_4',
#  '198 transpose_12/perm',
#  '199 transpose_12',
#  '200 Const_52',
#  '201 Pad_4',
#  '202 Const_53',
#  '203 split_8/split_dim',
#  '204 split_8',
#  '205 transpose_13/perm',
#  '206 transpose_13',
#  '207 Const_54',
#  '208 split_9/split_dim',
#  '209 split_9',
#  '210 convolution_4/dilation_rate',
#  '211 convolution_4',
#  '212 concat_4/concat_dim',
#  '213 concat_4',
#  '214 Add_4',
#  '215 transpose_14/perm',
#  '216 transpose_14',
#  '217 Reshape_8/shape',
#  '218 Reshape_8',
#  '219 Reshape_9/shape',
#  '220 Reshape_9',
#  '221 moments_4/mean/reduction_indices',
#  '222 moments_4/mean',
#  '223 moments_4/StopGradient',
#  '224 moments_4/SquaredDifference',
#  '225 moments_4/variance/reduction_indices',
#  '226 moments_4/variance',
#  '227 instancenorm_4/add/y',
#  '228 instancenorm_4/add',
#  '229 instancenorm_4/Rsqrt',
#  '230 instancenorm_4/mul',
#  '231 instancenorm_4/mul_1',
#  '232 instancenorm_4/mul_2',
#  '233 instancenorm_4/sub',
#  '234 instancenorm_4/add_1',
#  '235 Add_5',
#  '236 transpose_15/perm',
#  '237 transpose_15',
#  '238 Const_55',
#  '239 Pad_5',
#  '240 Const_56',
#  '241 split_10/split_dim',
#  '242 split_10',
#  '243 transpose_16/perm',
#  '244 transpose_16',
#  '245 Const_57',
#  '246 split_11/split_dim',
#  '247 split_11',
#  '248 convolution_5/dilation_rate',
#  '249 convolution_5',
#  '250 convolution_6/dilation_rate',
#  '251 convolution_6',
#  '252 convolution_7/dilation_rate',
#  '253 convolution_7',
#  '254 convolution_8/dilation_rate',
#  '255 convolution_8',
#  '256 convolution_9/dilation_rate',
#  '257 convolution_9',
#  '258 convolution_10/dilation_rate',
#  '259 convolution_10',
#  '260 convolution_11/dilation_rate',
#  '261 convolution_11',
#  '262 convolution_12/dilation_rate',
#  '263 convolution_12',
#  '264 convolution_13/dilation_rate',
#  '265 convolution_13',
#  '266 convolution_14/dilation_rate',
#  '267 convolution_14',
#  '268 convolution_15/dilation_rate',
#  '269 convolution_15',
#  '270 convolution_16/dilation_rate',
#  '271 convolution_16',
#  '272 convolution_17/dilation_rate',
#  '273 convolution_17',
#  '274 convolution_18/dilation_rate',
#  '275 convolution_18',
#  '276 convolution_19/dilation_rate',
#  '277 convolution_19',
#  '278 convolution_20/dilation_rate',
#  '279 convolution_20',
#  '280 convolution_21/dilation_rate',
#  '281 convolution_21',
#  '282 convolution_22/dilation_rate',
#  '283 convolution_22',
#  '284 convolution_23/dilation_rate',
#  '285 convolution_23',
#  '286 convolution_24/dilation_rate',
#  '287 convolution_24',
#  '288 convolution_25/dilation_rate',
#  '289 convolution_25',
#  '290 convolution_26/dilation_rate',
#  '291 convolution_26',
#  '292 convolution_27/dilation_rate',
#  '293 convolution_27',
#  '294 convolution_28/dilation_rate',
#  '295 convolution_28',
#  '296 convolution_29/dilation_rate',
#  '297 convolution_29',
#  '298 convolution_30/dilation_rate',
#  '299 convolution_30',
#  '300 convolution_31/dilation_rate',
#  '301 convolution_31',
#  '302 convolution_32/dilation_rate',
#  '303 convolution_32',
#  '304 convolution_33/dilation_rate',
#  '305 convolution_33',
#  '306 convolution_34/dilation_rate',
#  '307 convolution_34',
#  '308 convolution_35/dilation_rate',
#  '309 convolution_35',
#  '310 convolution_36/dilation_rate',
#  '311 convolution_36',
#  '312 concat_5/axis',
#  '313 concat_5',
#  '314 transpose_17/perm',
#  '315 transpose_17',
#  '316 Const_58',
#  '317 MirrorPad_5',
#  '318 transpose_18/perm',
#  '319 transpose_18',
#  '320 Const_59',
#  '321 Pad_6',
#  '322 Const_60',
#  '323 split_12/split_dim',
#  '324 split_12',
#  '325 transpose_19/perm',
#  '326 transpose_19',
#  '327 Const_61',
#  '328 split_13/split_dim',
#  '329 split_13',
#  '330 convolution_37/dilation_rate',
#  '331 convolution_37',
#  '332 concat_6/concat_dim',
#  '333 concat_6',
#  '334 Add_6',
#  '335 transpose_20/perm',
#  '336 transpose_20',
#  '337 Reshape_10/shape',
#  '338 Reshape_10',
#  '339 Reshape_11/shape',
#  '340 Reshape_11',
#  '341 moments_5/mean/reduction_indices',
#  '342 moments_5/mean',
#  '343 moments_5/StopGradient',
#  '344 moments_5/SquaredDifference',
#  '345 moments_5/variance/reduction_indices',
#  '346 moments_5/variance',
#  '347 instancenorm_5/add/y',
#  '348 instancenorm_5/add',
#  '349 instancenorm_5/Rsqrt',
#  '350 instancenorm_5/mul',
#  '351 instancenorm_5/mul_1',
#  '352 instancenorm_5/mul_2',
#  '353 instancenorm_5/sub',
#  '354 instancenorm_5/add_1',
#  '355 Relu_4',
#  '356 Const_62',
#  '357 MirrorPad_6',
#  '358 transpose_21/perm',
#  '359 transpose_21',
#  '360 Const_63',
#  '361 Pad_7',
#  '362 Const_64',
#  '363 split_14/split_dim',
#  '364 split_14',
#  '365 transpose_22/perm',
#  '366 transpose_22',
#  '367 Const_65',
#  '368 split_15/split_dim',
#  '369 split_15',
#  '370 convolution_38/dilation_rate',
#  '371 convolution_38',
#  '372 concat_7/concat_dim',
#  '373 concat_7',
#  '374 Add_7',
#  '375 transpose_23/perm',
#  '376 transpose_23',
#  '377 Reshape_12/shape',
#  '378 Reshape_12',
#  '379 Reshape_13/shape',
#  '380 Reshape_13',
#  '381 moments_6/mean/reduction_indices',
#  '382 moments_6/mean',
#  '383 moments_6/StopGradient',
#  '384 moments_6/SquaredDifference',
#  '385 moments_6/variance/reduction_indices',
#  '386 moments_6/variance',
#  '387 instancenorm_6/add/y',
#  '388 instancenorm_6/add',
#  '389 instancenorm_6/Rsqrt',
#  '390 instancenorm_6/mul',
#  '391 instancenorm_6/mul_1',
#  '392 instancenorm_6/mul_2',
#  '393 instancenorm_6/sub',
#  '394 instancenorm_6/add_1',
#  '395 Add_8',
#  '396 Const_66',
#  '397 MirrorPad_7',
#  '398 transpose_24/perm',
#  '399 transpose_24',
#  '400 Const_67',
#  '401 Pad_8',
#  '402 Const_68',
#  '403 split_16/split_dim',
#  '404 split_16',
#  '405 transpose_25/perm',
#  '406 transpose_25',
#  '407 Const_69',
#  '408 split_17/split_dim',
#  '409 split_17',
#  '410 convolution_39/dilation_rate',
#  '411 convolution_39',
#  '412 concat_8/concat_dim',
#  '413 concat_8',
#  '414 Add_9',
#  '415 transpose_26/perm',
#  '416 transpose_26',
#  '417 Reshape_14/shape',
#  '418 Reshape_14',
#  '419 Reshape_15/shape',
#  '420 Reshape_15',
#  '421 moments_7/mean/reduction_indices',
#  '422 moments_7/mean',
#  '423 moments_7/StopGradient',
#  '424 moments_7/SquaredDifference',
#  '425 moments_7/variance/reduction_indices',
#  '426 moments_7/variance',
#  '427 instancenorm_7/add/y',
#  '428 instancenorm_7/add',
#  '429 instancenorm_7/Rsqrt',
#  '430 instancenorm_7/mul',
#  '431 instancenorm_7/mul_1',
#  '432 instancenorm_7/mul_2',
#  '433 instancenorm_7/sub',
#  '434 instancenorm_7/add_1',
#  '435 Relu_5',
#  '436 Const_70',
#  '437 strided_slice/stack',
#  '438 strided_slice/stack_1',
#  '439 strided_slice/stack_2',
#  '440 strided_slice',
#  '441 Equal/y',
#  '442 Equal',
#  '443 strided_slice_1/stack',
#  '444 strided_slice_1/stack_1',
#  '445 strided_slice_1/stack_2',
#  '446 strided_slice_1',
#  '447 Equal_1/y',
#  '448 Equal_1',
#  '449 LogicalAnd',
#  '450 Assert/AssertGuard/Switch',
#  '451 Assert/AssertGuard/switch_t',
#  '452 Assert/AssertGuard/switch_f',
#  '453 Assert/AssertGuard/pred_id',
#  '454 Assert/AssertGuard/NoOp',
#  '455 Assert/AssertGuard/control_dependency',
#  '456 Assert/AssertGuard/Assert',
#  '457 Assert/AssertGuard/Assert/Switch',
#  '458 Assert/AssertGuard/Assert/Switch_1',
#  '459 Assert/AssertGuard/control_dependency_1',
#  '460 Assert/AssertGuard/Merge',
#  '461 strided_slice_2/stack',
#  '462 strided_slice_2/stack_1',
#  '463 strided_slice_2/stack_2',
#  '464 strided_slice_2',
#  '465 mul/y',
#  '466 mul',
#  '467 Cast',
#  '468 transpose_27/perm',
#  '469 transpose_27',
#  '470 resize/ResizeNearestNeighbor',
#  '471 transpose_28/perm',
#  '472 transpose_28',
#  '473 Const_71',
#  '474 MirrorPad_8',
#  '475 transpose_29/perm',
#  '476 transpose_29',
#  '477 Const_72',
#  '478 Pad_9',
#  '479 Const_73',
#  '480 split_18/split_dim',
#  '481 split_18',
#  '482 transpose_30/perm',
#  '483 transpose_30',
#  '484 Const_74',
#  '485 split_19/split_dim',
#  '486 split_19',
#  '487 convolution_40/dilation_rate',
#  '488 convolution_40',
#  '489 concat_9/concat_dim',
#  '490 concat_9',
#  '491 Add_10',
#  '492 transpose_31/perm',
#  '493 transpose_31',
#  '494 Sigmoid']

# %%
# Tensorflow to Tensorflow Lite      IMPORTANT --input_arrays=0 --output_arrays=Sigmoid
# !tflite_convert --output_file=../models/model_fast.tflite --graph_def_file=../models/model_fast.pb --input_arrays=input.1 --output_arrays=Sigmoid --inference_type=FLOAT --post_training_quantize
# Out:
# 2019-02-21 21:05:59.890808: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-02-21 21:06:00.139431: I tensorflow/core/grappler/devices.cc:53] Number of eligible GPUs (core count >= 8): 0 (Note: TensorFlow was not compiled with CUDA support)
# 2019-02-21 21:06:00.141560: I tensorflow/core/grappler/clusters/single_machine.cc:359] Starting new session
# 2019-02-21 21:06:00.521412: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:586] Optimization results for grappler item: graph_to_optimize
# 2019-02-21 21:06:00.521439: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   model_pruner: Graph size after: 407 nodes (-88), 516 edges (-18), time = 24.064ms.
# 2019-02-21 21:06:00.521448: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   function_optimizer: Graph size after: 407 nodes (0), 516 edges (0), time = 2.411ms.
# 2019-02-21 21:06:00.521455: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   constant folding: Graph size after: 348 nodes (-59), 418 edges (-98), time = 126.816ms.
# 2019-02-21 21:06:00.521459: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   shape_optimizer: Graph size after: 348 nodes (0), 418 edges (0), time = 1.438ms.
# 2019-02-21 21:06:00.521465: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   arithmetic_optimizer: Graph size after: 280 nodes (-68), 416 edges (-2), time = 39.334ms.
# 2019-02-21 21:06:00.521508: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   loop_optimizer: Graph size after: 277 nodes (-3), 410 edges (-6), time = 2.072ms.
# 2019-02-21 21:06:00.521521: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   dependency_optimizer: Graph size after: 254 nodes (-23), 366 edges (-44), time = 7.187ms.
# 2019-02-21 21:06:00.521527: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   layout: Graph size after: 254 nodes (0), 366 edges (0), time = 1.934ms.
# 2019-02-21 21:06:00.521532: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   memory_optimizer: Graph size after: 254 nodes (0), 366 edges (0), time = 54.601ms.
# 2019-02-21 21:06:00.521537: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   model_pruner: Graph size after: 250 nodes (-4), 362 edges (-4), time = 2.308ms.
# 2019-02-21 21:06:00.521541: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   function_optimizer: Graph size after: 250 nodes (0), 362 edges (0), time = 0.793ms.
# 2019-02-21 21:06:00.521731: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   constant folding: Graph size after: 250 nodes (0), 362 edges (0), time = 9.947ms.
# 2019-02-21 21:06:00.521752: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   shape_optimizer: Graph size after: 250 nodes (0), 362 edges (0), time = 2.194ms.
# 2019-02-21 21:06:00.521760: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   arithmetic_optimizer: Graph size after: 248 nodes (-2), 362 edges (0), time = 11.556ms.
# 2019-02-21 21:06:00.521765: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   dependency_optimizer: Graph size after: 248 nodes (0), 362 edges (0), time = 6.349ms.
