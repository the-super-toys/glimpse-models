# %%
import torch
from torch import nn
import torch.onnx
import tensorflow as tf 
from onnx_tf.backend import prepare
import onnx

# %%
class ResBlock(nn.Module):
    def __init__(self, channels):
        super(ResBlock, self).__init__()
        
        self.resblock = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(channels, channels, kernel_size=3),
            nn.InstanceNorm2d(channels, affine=True),
            nn.ReLU(),
            nn.ReflectionPad2d(1),
            nn.Conv2d(channels, channels, kernel_size=3),
            nn.InstanceNorm2d(channels, affine=True),
        )
        
    def forward(self, x):
        out = self.resblock(x)
        return out + x
    
class Upsample2d(nn.Module):
    def __init__(self, scale_factor):
        super(Upsample2d, self).__init__()
        
        self.interp = nn.functional.interpolate
        self.scale_factor = scale_factor
        
    def forward(self, x):
        x = self.interp(x, scale_factor=self.scale_factor, mode='nearest')
        return x

class MicroResNet(nn.Module):
    def __init__(self):
        super(MicroResNet, self).__init__()
        
        self.downsampler = nn.Sequential(
            nn.ReflectionPad2d(4),
            nn.Conv2d(3, 8, kernel_size=9, stride=4),
            nn.InstanceNorm2d(8, affine=True),
            nn.ReLU(),
            nn.ReflectionPad2d(1),
            nn.Conv2d(8, 16, kernel_size=3, stride=2),
            nn.InstanceNorm2d(16, affine=True),
            nn.ReLU(),
            nn.ReflectionPad2d(1),
            nn.Conv2d(16, 32, kernel_size=3, stride=2),
            nn.InstanceNorm2d(32, affine=True),
            nn.ReLU(),
        )
        
        self.residual = nn.Sequential(
            ResBlock(32),
            nn.Conv2d(32, 64, kernel_size=1, bias=False, groups=32),
            ResBlock(64),
            nn.Conv2d(64, 128, kernel_size=1, bias=False, groups=64),
            ResBlock(128),
        )
        
        self.segmentator = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(128, 16, kernel_size=3),
            nn.InstanceNorm2d(16, affine=True),
            nn.ReLU(),
            Upsample2d(scale_factor=2),
            nn.ReflectionPad2d(4),
            nn.Conv2d(16, 1, kernel_size=9),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        out = self.downsampler(x)
        out = self.residual(out)
        out = self.segmentator(out)
        return out

# %%
model = MicroResNet()

checkpoint = torch.load('saliency_model_v8.pt')
model.load_state_dict(checkpoint)
model.eval()
# Out:
# MicroResNet(
#   (downsampler): Sequential(
#     (0): ReflectionPad2d((4, 4, 4, 4))
#     (1): Conv2d(3, 8, kernel_size=(9, 9), stride=(4, 4))
#     (2): InstanceNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (3): ReLU()
#     (4): ReflectionPad2d((1, 1, 1, 1))
#     (5): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2))
#     (6): InstanceNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (7): ReLU()
#     (8): ReflectionPad2d((1, 1, 1, 1))
#     (9): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2))
#     (10): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (11): ReLU()
#   )
#   (residual): Sequential(
#     (0): ResBlock(
#       (resblock): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (3): ReLU()
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       )
#     )
#     (1): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), groups=32, bias=False)
#     (2): ResBlock(
#       (resblock): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (3): ReLU()
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       )
#     )
#     (3): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), groups=64, bias=False)
#     (4): ResBlock(
#       (resblock): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         (3): ReLU()
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       )
#     )
#   )
#   (segmentator): Sequential(
#     (0): ReflectionPad2d((1, 1, 1, 1))
#     (1): Conv2d(128, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): InstanceNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (3): ReLU()
#     (4): Upsample2d()
#     (5): ReflectionPad2d((4, 4, 4, 4))
#     (6): Conv2d(16, 1, kernel_size=(9, 9), stride=(1, 1))
#     (7): Sigmoid()
#   )
# )

# %%
class MicroResNetIOS(nn.Module):
    def __init__(self):
        super(MicroResNetIOS, self).__init__()
        self.micro_res_net = model
        
    def forward(self, x):
        x = x.permute(0,3,1,2)
        out = self.micro_res_net(x)
        return out.permute(0,2,3,1)

model_ios = MicroResNetIOS()

# %%
with torch.no_grad():
    x = torch.randn(1, 3, 240, 320, requires_grad=True)
    torch_out = torch.onnx.export(model, x, "saliency_fast_2.onnx", export_params=True)

# %%
onnx_model = onnx.load("saliency_fast_2.onnx")  # load onnx model
tf_rep = prepare(onnx_model)  # prepare tf representation
tf_rep.export_graph("saliency_fast_2.pb")  # export the model

# %%
g = tf.GraphDef()
g.ParseFromString(open("saliency_fast_2.pb", "rb").read())

# g.node
[str(idx)+" "+n.name for (idx, n) in enumerate(g.node)] #if n.name == 'PyFunc']
# Out:
# ['0 Const',
#  '1 Const_1',
#  '2 Const_2',
#  '3 Const_3',
#  '4 Const_4',
#  '5 Const_5',
#  '6 Const_6',
#  '7 Const_7',
#  '8 Const_8',
#  '9 Const_9',
#  '10 Const_10',
#  '11 Const_11',
#  '12 Const_12',
#  '13 Const_13',
#  '14 Const_14',
#  '15 Const_15',
#  '16 Const_16',
#  '17 Const_17',
#  '18 Const_18',
#  '19 Const_19',
#  '20 Const_20',
#  '21 Const_21',
#  '22 Const_22',
#  '23 Const_23',
#  '24 Const_24',
#  '25 Const_25',
#  '26 Const_26',
#  '27 Const_27',
#  '28 Const_28',
#  '29 Const_29',
#  '30 Const_30',
#  '31 Const_31',
#  '32 Const_32',
#  '33 Const_33',
#  '34 Const_34',
#  '35 Const_35',
#  '36 Const_36',
#  '37 Const_37',
#  '38 Const_38',
#  '39 Const_39',
#  '40 Const_40',
#  '41 Const_41',
#  '42 Const_42',
#  '43 Const_43',
#  '44 input.1',
#  '45 Const_44',
#  '46 MirrorPad',
#  '47 transpose/perm',
#  '48 transpose',
#  '49 Const_45',
#  '50 Pad',
#  '51 Const_46',
#  '52 split/split_dim',
#  '53 split',
#  '54 transpose_1/perm',
#  '55 transpose_1',
#  '56 Const_47',
#  '57 split_1/split_dim',
#  '58 split_1',
#  '59 convolution/dilation_rate',
#  '60 convolution',
#  '61 concat/concat_dim',
#  '62 concat',
#  '63 Add',
#  '64 transpose_2/perm',
#  '65 transpose_2',
#  '66 Reshape/shape',
#  '67 Reshape',
#  '68 Reshape_1/shape',
#  '69 Reshape_1',
#  '70 moments/mean/reduction_indices',
#  '71 moments/mean',
#  '72 moments/StopGradient',
#  '73 moments/SquaredDifference',
#  '74 moments/variance/reduction_indices',
#  '75 moments/variance',
#  '76 instancenorm/add/y',
#  '77 instancenorm/add',
#  '78 instancenorm/Rsqrt',
#  '79 instancenorm/mul',
#  '80 instancenorm/mul_1',
#  '81 instancenorm/mul_2',
#  '82 instancenorm/sub',
#  '83 instancenorm/add_1',
#  '84 Relu',
#  '85 Const_48',
#  '86 MirrorPad_1',
#  '87 transpose_3/perm',
#  '88 transpose_3',
#  '89 Const_49',
#  '90 Pad_1',
#  '91 Const_50',
#  '92 split_2/split_dim',
#  '93 split_2',
#  '94 transpose_4/perm',
#  '95 transpose_4',
#  '96 Const_51',
#  '97 split_3/split_dim',
#  '98 split_3',
#  '99 convolution_1/dilation_rate',
#  '100 convolution_1',
#  '101 concat_1/concat_dim',
#  '102 concat_1',
#  '103 Add_1',
#  '104 transpose_5/perm',
#  '105 transpose_5',
#  '106 Reshape_2/shape',
#  '107 Reshape_2',
#  '108 Reshape_3/shape',
#  '109 Reshape_3',
#  '110 moments_1/mean/reduction_indices',
#  '111 moments_1/mean',
#  '112 moments_1/StopGradient',
#  '113 moments_1/SquaredDifference',
#  '114 moments_1/variance/reduction_indices',
#  '115 moments_1/variance',
#  '116 instancenorm_1/add/y',
#  '117 instancenorm_1/add',
#  '118 instancenorm_1/Rsqrt',
#  '119 instancenorm_1/mul',
#  '120 instancenorm_1/mul_1',
#  '121 instancenorm_1/mul_2',
#  '122 instancenorm_1/sub',
#  '123 instancenorm_1/add_1',
#  '124 Relu_1',
#  '125 Const_52',
#  '126 MirrorPad_2',
#  '127 transpose_6/perm',
#  '128 transpose_6',
#  '129 Const_53',
#  '130 Pad_2',
#  '131 Const_54',
#  '132 split_4/split_dim',
#  '133 split_4',
#  '134 transpose_7/perm',
#  '135 transpose_7',
#  '136 Const_55',
#  '137 split_5/split_dim',
#  '138 split_5',
#  '139 convolution_2/dilation_rate',
#  '140 convolution_2',
#  '141 concat_2/concat_dim',
#  '142 concat_2',
#  '143 Add_2',
#  '144 transpose_8/perm',
#  '145 transpose_8',
#  '146 Reshape_4/shape',
#  '147 Reshape_4',
#  '148 Reshape_5/shape',
#  '149 Reshape_5',
#  '150 moments_2/mean/reduction_indices',
#  '151 moments_2/mean',
#  '152 moments_2/StopGradient',
#  '153 moments_2/SquaredDifference',
#  '154 moments_2/variance/reduction_indices',
#  '155 moments_2/variance',
#  '156 instancenorm_2/add/y',
#  '157 instancenorm_2/add',
#  '158 instancenorm_2/Rsqrt',
#  '159 instancenorm_2/mul',
#  '160 instancenorm_2/mul_1',
#  '161 instancenorm_2/mul_2',
#  '162 instancenorm_2/sub',
#  '163 instancenorm_2/add_1',
#  '164 Relu_2',
#  '165 Const_56',
#  '166 MirrorPad_3',
#  '167 transpose_9/perm',
#  '168 transpose_9',
#  '169 Const_57',
#  '170 Pad_3',
#  '171 Const_58',
#  '172 split_6/split_dim',
#  '173 split_6',
#  '174 transpose_10/perm',
#  '175 transpose_10',
#  '176 Const_59',
#  '177 split_7/split_dim',
#  '178 split_7',
#  '179 convolution_3/dilation_rate',
#  '180 convolution_3',
#  '181 concat_3/concat_dim',
#  '182 concat_3',
#  '183 Add_3',
#  '184 transpose_11/perm',
#  '185 transpose_11',
#  '186 Reshape_6/shape',
#  '187 Reshape_6',
#  '188 Reshape_7/shape',
#  '189 Reshape_7',
#  '190 moments_3/mean/reduction_indices',
#  '191 moments_3/mean',
#  '192 moments_3/StopGradient',
#  '193 moments_3/SquaredDifference',
#  '194 moments_3/variance/reduction_indices',
#  '195 moments_3/variance',
#  '196 instancenorm_3/add/y',
#  '197 instancenorm_3/add',
#  '198 instancenorm_3/Rsqrt',
#  '199 instancenorm_3/mul',
#  '200 instancenorm_3/mul_1',
#  '201 instancenorm_3/mul_2',
#  '202 instancenorm_3/sub',
#  '203 instancenorm_3/add_1',
#  '204 Relu_3',
#  '205 Const_60',
#  '206 MirrorPad_4',
#  '207 transpose_12/perm',
#  '208 transpose_12',
#  '209 Const_61',
#  '210 Pad_4',
#  '211 Const_62',
#  '212 split_8/split_dim',
#  '213 split_8',
#  '214 transpose_13/perm',
#  '215 transpose_13',
#  '216 Const_63',
#  '217 split_9/split_dim',
#  '218 split_9',
#  '219 convolution_4/dilation_rate',
#  '220 convolution_4',
#  '221 concat_4/concat_dim',
#  '222 concat_4',
#  '223 Add_4',
#  '224 transpose_14/perm',
#  '225 transpose_14',
#  '226 Reshape_8/shape',
#  '227 Reshape_8',
#  '228 Reshape_9/shape',
#  '229 Reshape_9',
#  '230 moments_4/mean/reduction_indices',
#  '231 moments_4/mean',
#  '232 moments_4/StopGradient',
#  '233 moments_4/SquaredDifference',
#  '234 moments_4/variance/reduction_indices',
#  '235 moments_4/variance',
#  '236 instancenorm_4/add/y',
#  '237 instancenorm_4/add',
#  '238 instancenorm_4/Rsqrt',
#  '239 instancenorm_4/mul',
#  '240 instancenorm_4/mul_1',
#  '241 instancenorm_4/mul_2',
#  '242 instancenorm_4/sub',
#  '243 instancenorm_4/add_1',
#  '244 Add_5',
#  '245 transpose_15/perm',
#  '246 transpose_15',
#  '247 Const_64',
#  '248 Pad_5',
#  '249 Const_65',
#  '250 split_10/split_dim',
#  '251 split_10',
#  '252 transpose_16/perm',
#  '253 transpose_16',
#  '254 Const_66',
#  '255 split_11/split_dim',
#  '256 split_11',
#  '257 convolution_5/dilation_rate',
#  '258 convolution_5',
#  '259 convolution_6/dilation_rate',
#  '260 convolution_6',
#  '261 convolution_7/dilation_rate',
#  '262 convolution_7',
#  '263 convolution_8/dilation_rate',
#  '264 convolution_8',
#  '265 convolution_9/dilation_rate',
#  '266 convolution_9',
#  '267 convolution_10/dilation_rate',
#  '268 convolution_10',
#  '269 convolution_11/dilation_rate',
#  '270 convolution_11',
#  '271 convolution_12/dilation_rate',
#  '272 convolution_12',
#  '273 convolution_13/dilation_rate',
#  '274 convolution_13',
#  '275 convolution_14/dilation_rate',
#  '276 convolution_14',
#  '277 convolution_15/dilation_rate',
#  '278 convolution_15',
#  '279 convolution_16/dilation_rate',
#  '280 convolution_16',
#  '281 convolution_17/dilation_rate',
#  '282 convolution_17',
#  '283 convolution_18/dilation_rate',
#  '284 convolution_18',
#  '285 convolution_19/dilation_rate',
#  '286 convolution_19',
#  '287 convolution_20/dilation_rate',
#  '288 convolution_20',
#  '289 convolution_21/dilation_rate',
#  '290 convolution_21',
#  '291 convolution_22/dilation_rate',
#  '292 convolution_22',
#  '293 convolution_23/dilation_rate',
#  '294 convolution_23',
#  '295 convolution_24/dilation_rate',
#  '296 convolution_24',
#  '297 convolution_25/dilation_rate',
#  '298 convolution_25',
#  '299 convolution_26/dilation_rate',
#  '300 convolution_26',
#  '301 convolution_27/dilation_rate',
#  '302 convolution_27',
#  '303 convolution_28/dilation_rate',
#  '304 convolution_28',
#  '305 convolution_29/dilation_rate',
#  '306 convolution_29',
#  '307 convolution_30/dilation_rate',
#  '308 convolution_30',
#  '309 convolution_31/dilation_rate',
#  '310 convolution_31',
#  '311 convolution_32/dilation_rate',
#  '312 convolution_32',
#  '313 convolution_33/dilation_rate',
#  '314 convolution_33',
#  '315 convolution_34/dilation_rate',
#  '316 convolution_34',
#  '317 convolution_35/dilation_rate',
#  '318 convolution_35',
#  '319 convolution_36/dilation_rate',
#  '320 convolution_36',
#  '321 concat_5/axis',
#  '322 concat_5',
#  '323 transpose_17/perm',
#  '324 transpose_17',
#  '325 Const_67',
#  '326 MirrorPad_5',
#  '327 transpose_18/perm',
#  '328 transpose_18',
#  '329 Const_68',
#  '330 Pad_6',
#  '331 Const_69',
#  '332 split_12/split_dim',
#  '333 split_12',
#  '334 transpose_19/perm',
#  '335 transpose_19',
#  '336 Const_70',
#  '337 split_13/split_dim',
#  '338 split_13',
#  '339 convolution_37/dilation_rate',
#  '340 convolution_37',
#  '341 concat_6/concat_dim',
#  '342 concat_6',
#  '343 Add_6',
#  '344 transpose_20/perm',
#  '345 transpose_20',
#  '346 Reshape_10/shape',
#  '347 Reshape_10',
#  '348 Reshape_11/shape',
#  '349 Reshape_11',
#  '350 moments_5/mean/reduction_indices',
#  '351 moments_5/mean',
#  '352 moments_5/StopGradient',
#  '353 moments_5/SquaredDifference',
#  '354 moments_5/variance/reduction_indices',
#  '355 moments_5/variance',
#  '356 instancenorm_5/add/y',
#  '357 instancenorm_5/add',
#  '358 instancenorm_5/Rsqrt',
#  '359 instancenorm_5/mul',
#  '360 instancenorm_5/mul_1',
#  '361 instancenorm_5/mul_2',
#  '362 instancenorm_5/sub',
#  '363 instancenorm_5/add_1',
#  '364 Relu_4',
#  '365 Const_71',
#  '366 MirrorPad_6',
#  '367 transpose_21/perm',
#  '368 transpose_21',
#  '369 Const_72',
#  '370 Pad_7',
#  '371 Const_73',
#  '372 split_14/split_dim',
#  '373 split_14',
#  '374 transpose_22/perm',
#  '375 transpose_22',
#  '376 Const_74',
#  '377 split_15/split_dim',
#  '378 split_15',
#  '379 convolution_38/dilation_rate',
#  '380 convolution_38',
#  '381 concat_7/concat_dim',
#  '382 concat_7',
#  '383 Add_7',
#  '384 transpose_23/perm',
#  '385 transpose_23',
#  '386 Reshape_12/shape',
#  '387 Reshape_12',
#  '388 Reshape_13/shape',
#  '389 Reshape_13',
#  '390 moments_6/mean/reduction_indices',
#  '391 moments_6/mean',
#  '392 moments_6/StopGradient',
#  '393 moments_6/SquaredDifference',
#  '394 moments_6/variance/reduction_indices',
#  '395 moments_6/variance',
#  '396 instancenorm_6/add/y',
#  '397 instancenorm_6/add',
#  '398 instancenorm_6/Rsqrt',
#  '399 instancenorm_6/mul',
#  '400 instancenorm_6/mul_1',
#  '401 instancenorm_6/mul_2',
#  '402 instancenorm_6/sub',
#  '403 instancenorm_6/add_1',
#  '404 Add_8',
#  '405 transpose_24/perm',
#  '406 transpose_24',
#  '407 Const_75',
#  '408 Pad_8',
#  '409 Const_76',
#  '410 split_16/split_dim',
#  '411 split_16',
#  '412 transpose_25/perm',
#  '413 transpose_25',
#  '414 Const_77',
#  '415 split_17/split_dim',
#  '416 split_17',
#  '417 convolution_39/dilation_rate',
#  '418 convolution_39',
#  '419 convolution_40/dilation_rate',
#  '420 convolution_40',
#  '421 convolution_41/dilation_rate',
#  '422 convolution_41',
#  '423 convolution_42/dilation_rate',
#  '424 convolution_42',
#  '425 convolution_43/dilation_rate',
#  '426 convolution_43',
#  '427 convolution_44/dilation_rate',
#  '428 convolution_44',
#  '429 convolution_45/dilation_rate',
#  '430 convolution_45',
#  '431 convolution_46/dilation_rate',
#  '432 convolution_46',
#  '433 convolution_47/dilation_rate',
#  '434 convolution_47',
#  '435 convolution_48/dilation_rate',
#  '436 convolution_48',
#  '437 convolution_49/dilation_rate',
#  '438 convolution_49',
#  '439 convolution_50/dilation_rate',
#  '440 convolution_50',
#  '441 convolution_51/dilation_rate',
#  '442 convolution_51',
#  '443 convolution_52/dilation_rate',
#  '444 convolution_52',
#  '445 convolution_53/dilation_rate',
#  '446 convolution_53',
#  '447 convolution_54/dilation_rate',
#  '448 convolution_54',
#  '449 convolution_55/dilation_rate',
#  '450 convolution_55',
#  '451 convolution_56/dilation_rate',
#  '452 convolution_56',
#  '453 convolution_57/dilation_rate',
#  '454 convolution_57',
#  '455 convolution_58/dilation_rate',
#  '456 convolution_58',
#  '457 convolution_59/dilation_rate',
#  '458 convolution_59',
#  '459 convolution_60/dilation_rate',
#  '460 convolution_60',
#  '461 convolution_61/dilation_rate',
#  '462 convolution_61',
#  '463 convolution_62/dilation_rate',
#  '464 convolution_62',
#  '465 convolution_63/dilation_rate',
#  '466 convolution_63',
#  '467 convolution_64/dilation_rate',
#  '468 convolution_64',
#  '469 convolution_65/dilation_rate',
#  '470 convolution_65',
#  '471 convolution_66/dilation_rate',
#  '472 convolution_66',
#  '473 convolution_67/dilation_rate',
#  '474 convolution_67',
#  '475 convolution_68/dilation_rate',
#  '476 convolution_68',
#  '477 convolution_69/dilation_rate',
#  '478 convolution_69',
#  '479 convolution_70/dilation_rate',
#  '480 convolution_70',
#  '481 convolution_71/dilation_rate',
#  '482 convolution_71',
#  '483 convolution_72/dilation_rate',
#  '484 convolution_72',
#  '485 convolution_73/dilation_rate',
#  '486 convolution_73',
#  '487 convolution_74/dilation_rate',
#  '488 convolution_74',
#  '489 convolution_75/dilation_rate',
#  '490 convolution_75',
#  '491 convolution_76/dilation_rate',
#  '492 convolution_76',
#  '493 convolution_77/dilation_rate',
#  '494 convolution_77',
#  '495 convolution_78/dilation_rate',
#  '496 convolution_78',
#  '497 convolution_79/dilation_rate',
#  '498 convolution_79',
#  '499 convolution_80/dilation_rate',
#  '500 convolution_80',
#  '501 convolution_81/dilation_rate',
#  '502 convolution_81',
#  '503 convolution_82/dilation_rate',
#  '504 convolution_82',
#  '505 convolution_83/dilation_rate',
#  '506 convolution_83',
#  '507 convolution_84/dilation_rate',
#  '508 convolution_84',
#  '509 convolution_85/dilation_rate',
#  '510 convolution_85',
#  '511 convolution_86/dilation_rate',
#  '512 convolution_86',
#  '513 convolution_87/dilation_rate',
#  '514 convolution_87',
#  '515 convolution_88/dilation_rate',
#  '516 convolution_88',
#  '517 convolution_89/dilation_rate',
#  '518 convolution_89',
#  '519 convolution_90/dilation_rate',
#  '520 convolution_90',
#  '521 convolution_91/dilation_rate',
#  '522 convolution_91',
#  '523 convolution_92/dilation_rate',
#  '524 convolution_92',
#  '525 convolution_93/dilation_rate',
#  '526 convolution_93',
#  '527 convolution_94/dilation_rate',
#  '528 convolution_94',
#  '529 convolution_95/dilation_rate',
#  '530 convolution_95',
#  '531 convolution_96/dilation_rate',
#  '532 convolution_96',
#  '533 convolution_97/dilation_rate',
#  '534 convolution_97',
#  '535 convolution_98/dilation_rate',
#  '536 convolution_98',
#  '537 convolution_99/dilation_rate',
#  '538 convolution_99',
#  '539 convolution_100/dilation_rate',
#  '540 convolution_100',
#  '541 convolution_101/dilation_rate',
#  '542 convolution_101',
#  '543 convolution_102/dilation_rate',
#  '544 convolution_102',
#  '545 concat_8/axis',
#  '546 concat_8',
#  '547 transpose_26/perm',
#  '548 transpose_26',
#  '549 Const_78',
#  '550 MirrorPad_7',
#  '551 transpose_27/perm',
#  '552 transpose_27',
#  '553 Const_79',
#  '554 Pad_9',
#  '555 Const_80',
#  '556 split_18/split_dim',
#  '557 split_18',
#  '558 transpose_28/perm',
#  '559 transpose_28',
#  '560 Const_81',
#  '561 split_19/split_dim',
#  '562 split_19',
#  '563 convolution_103/dilation_rate',
#  '564 convolution_103',
#  '565 concat_9/concat_dim',
#  '566 concat_9',
#  '567 Add_9',
#  '568 transpose_29/perm',
#  '569 transpose_29',
#  '570 Reshape_14/shape',
#  '571 Reshape_14',
#  '572 Reshape_15/shape',
#  '573 Reshape_15',
#  '574 moments_7/mean/reduction_indices',
#  '575 moments_7/mean',
#  '576 moments_7/StopGradient',
#  '577 moments_7/SquaredDifference',
#  '578 moments_7/variance/reduction_indices',
#  '579 moments_7/variance',
#  '580 instancenorm_7/add/y',
#  '581 instancenorm_7/add',
#  '582 instancenorm_7/Rsqrt',
#  '583 instancenorm_7/mul',
#  '584 instancenorm_7/mul_1',
#  '585 instancenorm_7/mul_2',
#  '586 instancenorm_7/sub',
#  '587 instancenorm_7/add_1',
#  '588 Relu_5',
#  '589 Const_82',
#  '590 MirrorPad_8',
#  '591 transpose_30/perm',
#  '592 transpose_30',
#  '593 Const_83',
#  '594 Pad_10',
#  '595 Const_84',
#  '596 split_20/split_dim',
#  '597 split_20',
#  '598 transpose_31/perm',
#  '599 transpose_31',
#  '600 Const_85',
#  '601 split_21/split_dim',
#  '602 split_21',
#  '603 convolution_104/dilation_rate',
#  '604 convolution_104',
#  '605 concat_10/concat_dim',
#  '606 concat_10',
#  '607 Add_10',
#  '608 transpose_32/perm',
#  '609 transpose_32',
#  '610 Reshape_16/shape',
#  '611 Reshape_16',
#  '612 Reshape_17/shape',
#  '613 Reshape_17',
#  '614 moments_8/mean/reduction_indices',
#  '615 moments_8/mean',
#  '616 moments_8/StopGradient',
#  '617 moments_8/SquaredDifference',
#  '618 moments_8/variance/reduction_indices',
#  '619 moments_8/variance',
#  '620 instancenorm_8/add/y',
#  '621 instancenorm_8/add',
#  '622 instancenorm_8/Rsqrt',
#  '623 instancenorm_8/mul',
#  '624 instancenorm_8/mul_1',
#  '625 instancenorm_8/mul_2',
#  '626 instancenorm_8/sub',
#  '627 instancenorm_8/add_1',
#  '628 Add_11',
#  '629 Const_86',
#  '630 MirrorPad_9',
#  '631 transpose_33/perm',
#  '632 transpose_33',
#  '633 Const_87',
#  '634 Pad_11',
#  '635 Const_88',
#  '636 split_22/split_dim',
#  '637 split_22',
#  '638 transpose_34/perm',
#  '639 transpose_34',
#  '640 Const_89',
#  '641 split_23/split_dim',
#  '642 split_23',
#  '643 convolution_105/dilation_rate',
#  '644 convolution_105',
#  '645 concat_11/concat_dim',
#  '646 concat_11',
#  '647 Add_12',
#  '648 transpose_35/perm',
#  '649 transpose_35',
#  '650 Reshape_18/shape',
#  '651 Reshape_18',
#  '652 Reshape_19/shape',
#  '653 Reshape_19',
#  '654 moments_9/mean/reduction_indices',
#  '655 moments_9/mean',
#  '656 moments_9/StopGradient',
#  '657 moments_9/SquaredDifference',
#  '658 moments_9/variance/reduction_indices',
#  '659 moments_9/variance',
#  '660 instancenorm_9/add/y',
#  '661 instancenorm_9/add',
#  '662 instancenorm_9/Rsqrt',
#  '663 instancenorm_9/mul',
#  '664 instancenorm_9/mul_1',
#  '665 instancenorm_9/mul_2',
#  '666 instancenorm_9/sub',
#  '667 instancenorm_9/add_1',
#  '668 Relu_6',
#  '669 Const_90',
#  '670 strided_slice/stack',
#  '671 strided_slice/stack_1',
#  '672 strided_slice/stack_2',
#  '673 strided_slice',
#  '674 Equal/y',
#  '675 Equal',
#  '676 strided_slice_1/stack',
#  '677 strided_slice_1/stack_1',
#  '678 strided_slice_1/stack_2',
#  '679 strided_slice_1',
#  '680 Equal_1/y',
#  '681 Equal_1',
#  '682 LogicalAnd',
#  '683 Assert/AssertGuard/Switch',
#  '684 Assert/AssertGuard/switch_t',
#  '685 Assert/AssertGuard/switch_f',
#  '686 Assert/AssertGuard/pred_id',
#  '687 Assert/AssertGuard/NoOp',
#  '688 Assert/AssertGuard/control_dependency',
#  '689 Assert/AssertGuard/Assert',
#  '690 Assert/AssertGuard/Assert/Switch',
#  '691 Assert/AssertGuard/Assert/Switch_1',
#  '692 Assert/AssertGuard/control_dependency_1',
#  '693 Assert/AssertGuard/Merge',
#  '694 strided_slice_2/stack',
#  '695 strided_slice_2/stack_1',
#  '696 strided_slice_2/stack_2',
#  '697 strided_slice_2',
#  '698 mul/y',
#  '699 mul',
#  '700 Cast',
#  '701 transpose_36/perm',
#  '702 transpose_36',
#  '703 resize/ResizeNearestNeighbor',
#  '704 transpose_37/perm',
#  '705 transpose_37',
#  '706 Const_91',
#  '707 MirrorPad_10',
#  '708 transpose_38/perm',
#  '709 transpose_38',
#  '710 Const_92',
#  '711 Pad_12',
#  '712 Const_93',
#  '713 split_24/split_dim',
#  '714 split_24',
#  '715 transpose_39/perm',
#  '716 transpose_39',
#  '717 Const_94',
#  '718 split_25/split_dim',
#  '719 split_25',
#  '720 convolution_106/dilation_rate',
#  '721 convolution_106',
#  '722 concat_12/concat_dim',
#  '723 concat_12',
#  '724 Add_13',
#  '725 transpose_40/perm',
#  '726 transpose_40',
#  '727 Sigmoid']

# %%
# Tensorflow to Tensorflow Lite      IMPORTANT --input_arrays=0 --output_arrays=Sigmoid
# !tflite_convert --output_file=saliency_fast_2.tflite --graph_def_file=saliency_fast_2.pb --input_arrays=input.1 --output_arrays=Sigmoid --inference_type=FLOAT --post_training_quantize
# Out:
# 2019-02-15 09:30:38.109137: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-02-15 09:30:38.249003: I tensorflow/core/grappler/devices.cc:53] Number of eligible GPUs (core count >= 8): 0 (Note: TensorFlow was not compiled with CUDA support)
# 2019-02-15 09:30:38.249104: I tensorflow/core/grappler/clusters/single_machine.cc:359] Starting new session
# 2019-02-15 09:30:38.437885: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:586] Optimization results for grappler item: graph_to_optimize
# 2019-02-15 09:30:38.437910: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   model_pruner: Graph size after: 562 nodes (-166), 806 edges (-22), time = 7.993ms.
# 2019-02-15 09:30:38.437916: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   function_optimizer: Graph size after: 562 nodes (0), 806 edges (0), time = 2.073ms.
# 2019-02-15 09:30:38.437939: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   constant folding: Graph size after: 546 nodes (-16), 688 edges (-118), time = 49.873ms.
# 2019-02-15 09:30:38.437944: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   shape_optimizer: Graph size after: 546 nodes (0), 688 edges (0), time = 2.524ms.
# 2019-02-15 09:30:38.437948: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   arithmetic_optimizer: Graph size after: 452 nodes (-94), 696 edges (8), time = 16.027ms.
# 2019-02-15 09:30:38.438652: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   loop_optimizer: Graph size after: 449 nodes (-3), 690 edges (-6), time = 3.114ms.
# 2019-02-15 09:30:38.438662: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   dependency_optimizer: Graph size after: 406 nodes (-43), 606 edges (-84), time = 6.556ms.
# 2019-02-15 09:30:38.438668: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   layout: Graph size after: 406 nodes (0), 606 edges (0), time = 1.442ms.
# 2019-02-15 09:30:38.438673: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   memory_optimizer: Graph size after: 406 nodes (0), 606 edges (0), time = 33.519ms.
# 2019-02-15 09:30:38.438678: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   model_pruner: Graph size after: 402 nodes (-4), 602 edges (-4), time = 2.611ms.
# 2019-02-15 09:30:38.438683: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   function_optimizer: Graph size after: 402 nodes (0), 602 edges (0), time = 1.658ms.
# 2019-02-15 09:30:38.438856: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   constant folding: Graph size after: 402 nodes (0), 602 edges (0), time = 14.728ms.
# 2019-02-15 09:30:38.438882: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   shape_optimizer: Graph size after: 402 nodes (0), 602 edges (0), time = 2.001ms.
# 2019-02-15 09:30:38.438900: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   arithmetic_optimizer: Graph size after: 400 nodes (-2), 602 edges (0), time = 13.602ms.
# 2019-02-15 09:30:38.438905: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:588]   dependency_optimizer: Graph size after: 400 nodes (0), 602 edges (0), time = 6.023ms.
